# %%
import nest
import matplotlib.pyplot as plt
# Out:
#               -- N E S T --
#   Copyright (C) 2004 The NEST Initiative
#
#  Version: 3.3
#  Built: Aug  9 2022 10:44:45
#
#  This program is provided AS IS and comes with
#  NO WARRANTY. See the file LICENSE for details.
#
#  Problems or suggestions?
#    Visit https://www.nest-simulator.org
#
#  Type 'nest.help()' to find out more about NEST.

# %%
import sys 
sys.path.append('..')

# %%
# !ls ..
# Out:
# assets	models	papers	README.md  requeriments.txt  results  src  tests  utils

# %%
import numpy as np
import matplotlib.pyplot as plt

from assets.potjans_diesmann.stimulus_params import stim_dict
from assets.potjans_diesmann.network_params import net_dict
from assets.potjans_diesmann.sim_params import sim_dict

from src import network_potjans_diesmann as network

# %%
nest.ResetKernel()
nest.local_num_threads = sim_dict['local_num_threads']
nest.resolution = sim_dict['sim_resolution']
nest.rng_seed = sim_dict['rng_seed']
nest.overwrite_files = sim_dict['overwrite_files']
nest.print_time = sim_dict['print_time']

if nest.Rank() == 0:
    print('RNG seed: {}'.format(
        nest.rng_seed))
    print('Total number of virtual processes: {}'.format(
        nest.total_num_virtual_procs))
# Out:
# RNG seed: 55
# Aug 01 14:21:27 SimulationManager::set_status [Info]:
#     Temporal resolution chan
# Total number of virtual processes: 1
# ged from 0.1 to 0.1 ms.

# %%
net_src = network.Network(sim_dict, net_dict, stim_dict)
net_src.create()
net_src.connect()

net_tg = network.Network(sim_dict, net_dict, stim_dict)
net_tg.create()
net_tg.connect()
# Out:
# Data will be written to: /home/camilo/AA_Work/CENIA/RL3/canonical_microcircuits/tests/results/potjans_diesmann/20230801142127
#   Directory has been created.
#
# Neuron numbers are scaled by a factor of 0.100.
# Indegrees are scaled by a factor of 0.100.
#   Weights and DC input are adjusted to compensate.
#
# Creating neuronal populations.
# Creating recording devices.
#   Creating spike recorders.
#   Creating voltmeters.
#   Creating poisson input meters.
# Creating Poisson generators for background input.
# Connecting neuronal populations recurrently.
# Connecting Poisson generators for background input.
# Data will be written to: /home/camilo/AA_Work/CENIA/RL3/canonical_microcircuits/tests/results/potjans_diesmann/20230801142127
#   Directory already existed. Old data will be overwritten.
#
#
# Aug 01 14:21:28 NodeManager::prepare_nodes [Info]:
#     Preparing 7749 nodes for simulation.
# Neuron numbers are scaled by a factor of 0.100.
# Indegrees are scaled by a factor of 0.100.
#   Weights and DC input are adjusted to compensate.
#
# Creating neuronal populations.
# Creating recording devices.
#   Creating spike recorders.
#   Creating voltmeters.
#   Creating poisson input meters.
# Creating Poisson generators for background input.
# Connecting neuronal populations recurrently.
# Connecting Poisson generators for background input.
#
# Aug 01 14:21:30 NodeManager::prepare_nodes [Info]:
#     Preparing 15498 nodes for simulation.

# %%
net_src.pops
# Out:
# [NodeCollection(metadata=None, model=iaf_psc_exp, size=2068, first=1, last=2068),
#  NodeCollection(metadata=None, model=iaf_psc_exp, size=583, first=2069, last=2651),
#  NodeCollection(metadata=None, model=iaf_psc_exp, size=2192, first=2652, last=4843),
#  NodeCollection(metadata=None, model=iaf_psc_exp, size=548, first=4844, last=5391),
#  NodeCollection(metadata=None, model=iaf_psc_exp, size=485, first=5392, last=5876),
#  NodeCollection(metadata=None, model=iaf_psc_exp, size=106, first=5877, last=5982),
#  NodeCollection(metadata=None, model=iaf_psc_exp, size=1440, first=5983, last=7422),
#  NodeCollection(metadata=None, model=iaf_psc_exp, size=295, first=7423, last=7717)]

# %%
net_tg.pops
# Out:
# [NodeCollection(metadata=None, model=iaf_psc_exp, size=2068, first=7750, last=9817),
#  NodeCollection(metadata=None, model=iaf_psc_exp, size=583, first=9818, last=10400),
#  NodeCollection(metadata=None, model=iaf_psc_exp, size=2192, first=10401, last=12592),
#  NodeCollection(metadata=None, model=iaf_psc_exp, size=548, first=12593, last=13140),
#  NodeCollection(metadata=None, model=iaf_psc_exp, size=485, first=13141, last=13625),
#  NodeCollection(metadata=None, model=iaf_psc_exp, size=106, first=13626, last=13731),
#  NodeCollection(metadata=None, model=iaf_psc_exp, size=1440, first=13732, last=15171),
#  NodeCollection(metadata=None, model=iaf_psc_exp, size=295, first=15172, last=15466)]

# %%
n1 = nest.Create('iaf_psc_exp', 1)
n2 = nest.Create('iaf_psc_exp', 1)
n3 = nest.Create('iaf_psc_exp', 1)

nest.Connect(n1, n1, 'all_to_all')
nest.Connect(n1, n3, 'all_to_all')
nest.Connect(n2, n3, 'all_to_all')

# %%
n1
# Out:
# NodeCollection(metadata=None, model=iaf_psc_exp, size=1, first=15499)

# %%
n2
# Out:
# NodeCollection(metadata=None, model=iaf_psc_exp, size=1, first=15500)

# %%
n3
# Out:
# NodeCollection(metadata=None, model=iaf_psc_exp, size=1, first=15501)

# %%
conn = nest.GetConnections()

# %%
conn.get()
# Out:
# Cannot execute code, session has been disposed. Please try restarting the Kernel.
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# Cannot execute code, session has been disposed. Please try restarting the Kernel.
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
